# %%
import pandas as pd
import numpy as np
import warnings
import datetime
import sys

from main import *
from transform import *

sys.path.append("../common")
from date_extractor import DateExtractor

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
company='mpr'

# %%
run = TransformDataSalesAccum(month='08', year='2024')
df_akum = run.transform_data_report()
# Out:
# Data This Month
# Amount is Matched
# Data Last Month
# please check the data there is unmatched amount
# Amount Before : 53803291873.79
# Amount After : 10902044297.29
# Data Last Year
# please check the data there is unmatched amount
# Amount Before : 54931334556.88
# Amount After : 9586952691.3

# %%
df[0]
# Out:
#        dataareaid brand   channel deptstore groupstore  cscode axcode whcode  \
# 0             mgl    PM  SHOWROOM  SHOWROOM   SHOWROOM  CS1618  C0001  20062
# 1             mgl    PM  SHOWROOM  SHOWROOM   SHOWROOM  CS1618  C0001  20062
# 2             mgl    PM  SHOWROOM  SHOWROOM   SHOWROOM  CS1618  C0001  20062
# 3             mgl    PM  SHOWROOM  SHOWROOM   SHOWROOM  CS1618  C0001  20062
# 4             mgl    PM  SHOWROOM  SHOWROOM   SHOWROOM  CS1618  C0001  20062
# ...           ...   ...       ...       ...        ...     ...    ...    ...
# 107962        mpr    MN    BAZAAR  SHOWROOM   SHOWROOM  CS2253  C1418  11512
# 107963        mpr    MN    BAZAAR  SHOWROOM   SHOWROOM  CS2253  C1418  11512
# 107964        mpr    MN    BAZAAR  SHOWROOM   SHOWROOM  CS2253  C1418  11512
# 107965        mpr    MN    BAZAAR  SHOWROOM   SHOWROOM  CS2253  C1418  11512
# 107966        mpr    MN    BAZAAR  SHOWROOM   SHOWROOM  CS2253  C1418  11512
#
#                             stdname    sqm      sssg openstatus  \
# 0        SHOWROOM PM EMPORIUM PLUIT  150.5      SSSG       OPEN
# 1        SHOWROOM PM EMPORIUM PLUIT  150.5      SSSG       OPEN
# 2        SHOWROOM PM EMPORIUM PLUIT  150.5      SSSG       OPEN
# 3        SHOWROOM PM EMPORIUM PLUIT  150.5      SSSG       OPEN
# 4        SHOWROOM PM EMPORIUM PLUIT  150.5      SSSG       OPEN
# ...                             ...    ...       ...        ...
# 107962  BAZAAR MN Q MALL BANJARBARU   20.0  NON SSSG    PLAN GO
# 107963  BAZAAR MN Q MALL BANJARBARU   20.0  NON SSSG    PLAN GO
# 107964  BAZAAR MN Q MALL BANJARBARU   20.0  NON SSSG    PLAN GO
# 107965  BAZAAR MN Q MALL BANJARBARU   20.0  NON SSSG    PLAN GO
# 107966  BAZAAR MN Q MALL BANJARBARU   20.0  NON SSSG    PLAN GO
#
#                so_dept_head        area_head                 city_head  \
# 0              Rahma Yunita  Henri Mediyanto  Henri Mediyanto (Direct)
# 1              Rahma Yunita  Henri Mediyanto  Henri Mediyanto (Direct)
# 2              Rahma Yunita  Henri Mediyanto  Henri Mediyanto (Direct)
# 3              Rahma Yunita  Henri Mediyanto  Henri Mediyanto (Direct)
# 4              Rahma Yunita  Henri Mediyanto  Henri Mediyanto (Direct)
# ...                     ...              ...                       ...
# 107962  Artha Erlina Gomgom         Harianti   Muhammad Yamin (Direct)
# 107963  Artha Erlina Gomgom         Harianti   Muhammad Yamin (Direct)
# 107964  Artha Erlina Gomgom         Harianti   Muhammad Yamin (Direct)
# 107965  Artha Erlina Gomgom         Harianti   Muhammad Yamin (Direct)
# 107966  Artha Erlina Gomgom         Harianti   Muhammad Yamin (Direct)
#
#              target  target_daily order_create_date  day  day_name  day_score  \
# 0       352000000.0  8.282353e+06        2024-08-01    1  Thursday        1.0
# 1               0.0  0.000000e+00        2024-08-01    1  Thursday        1.0
# 2               0.0  0.000000e+00        2024-08-01    1  Thursday        1.0
# 3               0.0  0.000000e+00        2024-08-01    1  Thursday        1.0
# 4               0.0  0.000000e+00        2024-08-01    1  Thursday        1.0
# ...             ...           ...               ...  ...       ...        ...
# 107962          0.0  0.000000e+00        2024-08-03    3  Saturday        2.0
# 107963          0.0  0.000000e+00        2024-08-03    3  Saturday        2.0
# 107964          0.0  0.000000e+00        2024-08-04    4    Sunday        2.0
# 107965          0.0  0.000000e+00        2024-08-04    4    Sunday        2.0
# 107966          0.0  0.000000e+00        2024-08-04    4    Sunday        2.0
#
#           week month  month_score         itemid umbrellabrand subbrand  \
# 0       Week 1    08         42.5  2312000018875          Puma
# 1       Week 1    08         42.5  2312000018888          Puma
# 2       Week 1    08         42.5  2312000018893          Puma
# 3       Week 1    08         42.5  2312000019316          Puma
# 4       Week 1    08         42.5  2312000019469          Puma
# ...        ...   ...          ...            ...           ...      ...
# 107962  Week 1    08         42.5  2312000015314       Minimal
# 107963  Week 1    08         42.5  2312000015315       Minimal
# 107964  Week 1    08         42.5  2312000013401       Minimal
# 107965  Week 1    08         42.5  2312000015020       Minimal
# 107966  Week 1    08         42.5  2312000015029       Minimal
#
#               world     category         subcategory  ordernumber  quantity  \
# 0       Accessories  Accessories                 Cap          0.0       0.0
# 1       Accessories  Accessories                 Cap          0.0       0.0
# 2       Accessories  Accessories                 Cap          0.0       0.0
# 3       Accessories  Accessories           Waist Bag          1.0       1.0
# 4       Accessories  Accessories        Backpack Bag          0.0       0.0
# ...             ...          ...                 ...          ...       ...
# 107962    Essential          Top               Shirt          1.0       1.0
# 107963    Essential          Top               Shirt          1.0       1.0
# 107964  Accessories          Bag           Tote Bags          1.0       1.0
# 107965     Everyday        Dress  Dress Short Sleeve          1.0       1.0
# 107966       Studio        Dress  Dress Short Sleeve          1.0       1.0
#
#         cust_paid_peritem  hpp_total  ordernumber_lm  quantity_lm  \
# 0                    0.00       0.00             0.0          0.0
# 1                    0.00       0.00             1.0          1.0
# 2                    0.00       0.00             1.0          1.0
# 3                25804.63  144729.00             0.0          0.0
# 4                    0.00       0.00             1.0          1.0
# ...                   ...        ...             ...          ...
# 107962          239900.00   64306.07             0.0          0.0
# 107963          239900.00   64427.86             0.0          0.0
# 107964            3000.00    2087.57             0.0          0.0
# 107965          200000.00  107319.98             0.0          0.0
# 107966          250000.00  132096.00             0.0          0.0
#
#         cust_paid_peritem_lm  hpp_total_lm  ordernumber_ly  quantity_ly  \
# 0                        0.0          0.00             1.0          1.0
# 1                   279500.0     264391.89             0.0          0.0
# 2                   279500.0     176261.00             0.0          0.0
# 3                        0.0          0.00             0.0          0.0
# 4                   279500.0     176262.00             0.0          0.0
# ...                      ...           ...             ...          ...
# 107962                   0.0          0.00             0.0          0.0
# 107963                   0.0          0.00             0.0          0.0
# 107964                   0.0          0.00             0.0          0.0
# 107965                   0.0          0.00             0.0          0.0
# 107966                   0.0          0.00             0.0          0.0
#
#         cust_paid_peritem_ly  hpp_total_ly
# 0                   599000.0     283310.81
# 1                        0.0          0.00
# 2                        0.0          0.00
# 3                        0.0          0.00
# 4                        0.0          0.00
# ...                      ...           ...
# 107962                   0.0          0.00
# 107963                   0.0          0.00
# 107964                   0.0          0.00
# 107965                   0.0          0.00
# 107966                   0.0          0.00
#
# [107967 rows x 42 columns]
